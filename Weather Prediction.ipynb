# %% [markdown]
# ## Weather Prediction

# %% [markdown]
# ![imgWeather.jpg](attachment:imgWeather.jpg)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("seattle-weather.csv")

# %% [markdown]
#  #### Data ----> https://www.kaggle.com/ananthr1/weather-prediction

# %%
data.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
data.tail()
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 1456  2015-12-27            8.6       4.4       1.7   2.9    rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3    rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6     fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4     sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5     sun

# %%
data.describe()
# Out:
#        precipitation     temp_max     temp_min         wind
# count    1461.000000  1461.000000  1461.000000  1461.000000
# mean        3.029432    16.439083     8.234771     3.241136
# std         6.680194     7.349758     5.023004     1.437825
# min         0.000000    -1.600000    -7.100000     0.400000
# 25%         0.000000    10.600000     4.400000     2.200000
# 50%         0.000000    15.600000     8.300000     3.000000
# 75%         2.800000    22.200000    12.200000     4.000000
# max        55.900000    35.600000    18.300000     9.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
data.isnull().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
#convert the data type into datetime
data['date'] = pd.to_datetime(data['date'])

# %%
data.nunique()
# Out:
# date             1461
# precipitation     111
# temp_max           67
# temp_min           55
# wind               79
# weather             5
# dtype: int64

# %% [markdown]
# ## Data Visulization :

# %%
plt.figure(figsize=(10,16))
sns.set_theme()
sns.countplot(x = 'weather',data = data,palette="Reds")
plt.xlabel("weather",fontweight='bold',size=20,)
plt.ylabel("Count",fontweight='bold',size=20)
plt.show()

# %% [markdown]
# #### Graphical representation between Date and  maximum Temperature

# %%
plt.figure(figsize=(18,9))
sns.set_theme()
sns.lineplot(x = 'date',y='temp_max',data=data,color='Violet')
plt.xlabel("Date",fontweight='bold',size=16)
plt.ylabel("Temp_Max",fontweight='bold',size=16)
plt.show()

# %% [markdown]
# #### Graphical representation between Date and  minimum Temperature

# %%
plt.figure(figsize=(18,9))
sns.set_theme()
sns.plot = sns.lineplot(data=data,x = 'date',y='temp_max', color='Green')
plt.xlabel("Date",fontweight='bold',size=18)
plt.ylabel("Temp_Min",fontweight='bold',size=18)
plt.show()

# %% [markdown]
# #### Graphical representation between Date and wind

# %%
plt.figure(figsize=(18,14))
sns.set_theme()
sns.lineplot(x = 'date',y='wind',data=data,color='blue')
plt.xlabel("Date",fontweight='bold',size=16)
plt.ylabel("wind",fontweight='bold',size=16)
plt.show()

# %%
plt.figure(figsize=(22,8))
sns.pairplot(data.drop('date',axis=1),hue='weather',palette="Reds")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(10,5))
sns.catplot(x='weather',y ='temp_max',data=data,palette="crest")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.catplot(x='weather',y ='temp_min',data=data,palette = "RdBu")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.catplot(x='weather',y ='wind',data=data,palette = "magma")
plt.show()

# %%
sns.catplot(x='weather',y ='precipitation',data=data,palette = "viridis")
plt.show()

# %% [markdown]
# #### Price Range vs all numerical factor

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

fig.suptitle('Price Range vs all numerical factor')

sns.scatterplot(ax=axes[0, 0], data=data, x='weather', y='precipitation')
sns.scatterplot(ax=axes[0, 1], data=data, x='weather', y='temp_max')
sns.scatterplot(ax=axes[1, 0], data=data, x='weather', y='temp_min')
sns.scatterplot(ax=axes[1, 1], data=data, x='weather', y='wind')
plt.show()

# %%
def LABEL_ENCODING(c1):
    from sklearn import preprocessing
    label_encoder = preprocessing.LabelEncoder()
    data[c1]= label_encoder.fit_transform(data[c1])
    data[c1].unique()
LABEL_ENCODING("weather")
data
# Out:
#            date  precipitation  temp_max  temp_min  wind  weather
# 0    2012-01-01            0.0      12.8       5.0   4.7        0
# 1    2012-01-02           10.9      10.6       2.8   4.5        2
# 2    2012-01-03            0.8      11.7       7.2   2.3        2
# 3    2012-01-04           20.3      12.2       5.6   4.7        2
# 4    2012-01-05            1.3       8.9       2.8   6.1        2
# ...         ...            ...       ...       ...   ...      ...
# 1456 2015-12-27            8.6       4.4       1.7   2.9        2
# 1457 2015-12-28            1.5       5.0       1.7   1.3        2
# 1458 2015-12-29            0.0       7.2       0.6   2.6        1
# 1459 2015-12-30            0.0       5.6      -1.0   3.4        4
# 1460 2015-12-31            0.0       5.6      -2.1   3.5        4
#
# [1461 rows x 6 columns]

# %%
data = data.drop('date',axis=1)

# %%
x = data.drop('weather',axis=1)
y = data['weather']

# %% [markdown]
# ## Splitting the data into Train and Test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1095, 4)
# (366, 4)
# (1095,)
# (366,)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([4, 2, 2, 4, 4, 2, 2, 2, 4, 4, 4, 2, 4, 4, 4, 4, 4, 2, 2, 2, 2, 2,
#        2, 4, 4, 4, 4, 2, 4, 4, 2, 4, 2, 2, 2, 2, 4, 2, 4, 2, 4, 2, 2, 2,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 4, 4, 4, 2, 4, 2, 4, 4, 4, 4, 4, 2,
#        4, 4, 4, 2, 2, 2, 2, 4, 4, 4, 4, 4, 2, 4, 4, 4, 2, 2, 2, 4, 4, 2,
#        4, 4, 4, 4, 2, 4, 2, 2, 4, 4, 4, 4, 2, 2, 4, 2, 2, 4, 2, 2, 4, 4,
#        2, 4, 2, 4, 4, 4, 4, 2, 2, 2, 4, 2, 4, 4, 4, 4, 4, 4, 4, 2, 4, 2,
#        4, 2, 2, 2, 4, 2, 4, 4, 2, 2, 4, 4, 4, 4, 2, 4, 4, 4, 4, 4, 4, 2,
#        4, 2, 4, 4, 4, 4, 4, 2, 2, 2, 2, 2, 4, 2, 2, 2, 4, 4, 4, 4, 2, 2,
#        4, 4, 4, 4, 4, 4, 2, 4, 2, 4, 4, 2, 2, 4, 4, 4, 4, 4, 2, 2, 4, 2,
#        4, 4, 2, 2, 4, 4, 2, 4, 2, 4, 4, 2, 2, 2, 2, 2, 4, 4, 4, 2, 2, 2,
#        4, 4, 4, 2, 4, 4, 4, 4, 4, 4, 2, 2, 2, 2, 2, 4, 2, 4, 2, 2, 4, 2,
#        4, 2, 2, 4, 4, 4, 4, 4, 4, 4, 2, 2, 4, 4, 4, 4, 4, 4, 2, 2, 4, 4,
#        4, 2, 4, 2, 4, 2, 4, 4, 2, 2, 4, 4, 4, 4, 2, 4, 2, 2, 2, 4, 4, 4,
# ...

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[  0   0   0   0  11]
#  [  0   0   3   0  28]
#  [  0   0 130   0  25]
#  [  0   0   6   0   0]
#  [  0   0  14   0 149]]

# %% [markdown]
# #### heatmap

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %%
acc1 = accuracy_score(y_test, y_pred)
print(f"Accuracy score: {acc1}")
# Out:
# Accuracy score: 0.7622950819672131

# %% [markdown]
# ## Support Vector Machine algorithm

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# ## Predict the test set result

# %%
y_pred = classifier.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc2 = accuracy_score(y_test, y_pred)
# Out:
# [[  0   0   0   0  11]
#  [  0   0   0   0  31]
#  [  0   0 126   0  29]
#  [  0   0   4   2   0]
#  [  0   0   0   0 163]]

# %%
print(f"Accuracy score: {acc2}")
# Out:
# Accuracy score: 0.7950819672131147

# %% [markdown]
# ## K-Nearest Neighbor(KNN) Algorithm

# %% [markdown]
# #### Training set

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[  1   1   3   0   6]
#  [  1   4   5   0  21]
#  [  0   3 127   0  25]
#  [  0   0   3   1   2]
#  [  5  17  26   0 115]]

# %%
acc3 = accuracy_score(y_test, y_pred)
print(f"Accuracy score: {acc3}")
# Out:
# Accuracy score: 0.6775956284153005

# %% [markdown]
# ### Naïve Bayes algorithm

# %% [markdown]
# ### Training set

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[  0   0   0   0  11]
#  [  0   0   0   0  31]
#  [  0   0 141   2  12]
#  [  0   0   2   4   0]
#  [  0   0   0   0 163]]

# %%
acc4 = accuracy_score(y_test, y_pred)
print(f"Accuracy score : {acc4}")
# Out:
# Accuracy score : 0.8415300546448088

# %% [markdown]
# ## Decision Tree algorithm

# %% [markdown]
# ### Trainging Set

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([4, 0, 2, 4, 4, 2, 2, 2, 4, 2, 0, 2, 4, 1, 0, 4, 1, 2, 2, 2, 2, 2,
#        2, 4, 4, 0, 4, 2, 0, 4, 2, 4, 3, 2, 2, 2, 0, 2, 0, 2, 4, 2, 2, 2,
#        4, 0, 4, 4, 4, 4, 4, 4, 4, 2, 2, 4, 4, 3, 4, 2, 4, 4, 4, 1, 1, 2,
#        4, 1, 4, 2, 2, 3, 2, 0, 1, 4, 2, 0, 2, 2, 4, 4, 2, 2, 2, 4, 4, 2,
#        4, 2, 4, 1, 2, 1, 2, 3, 4, 0, 4, 4, 2, 2, 4, 2, 2, 2, 2, 2, 4, 4,
#        2, 4, 2, 4, 4, 4, 4, 4, 2, 2, 4, 2, 2, 1, 2, 4, 4, 0, 4, 2, 4, 2,
#        4, 2, 2, 2, 2, 4, 4, 4, 2, 3, 4, 4, 4, 2, 2, 4, 4, 4, 4, 1, 4, 2,
#        1, 2, 0, 4, 2, 4, 4, 0, 2, 1, 2, 2, 4, 2, 2, 2, 1, 1, 2, 4, 2, 2,
#        4, 4, 4, 4, 4, 4, 2, 1, 2, 1, 4, 2, 2, 4, 4, 4, 1, 4, 2, 2, 4, 0,
#        2, 4, 2, 2, 1, 4, 2, 2, 2, 4, 1, 1, 3, 2, 2, 2, 1, 4, 1, 2, 2, 2,
#        1, 4, 4, 2, 4, 4, 2, 4, 2, 0, 0, 2, 2, 2, 2, 1, 2, 4, 2, 2, 4, 2,
#        4, 2, 2, 0, 2, 4, 0, 4, 4, 4, 2, 3, 4, 4, 4, 4, 4, 4, 2, 1, 4, 4,
#        1, 2, 4, 2, 4, 1, 4, 4, 2, 2, 0, 1, 2, 4, 2, 4, 2, 2, 2, 0, 0, 4,
# ...

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[  1   2   1   0   7]
#  [  6   8   1   0  16]
#  [  0   1 140   4  10]
#  [  0   0   3   3   0]
#  [ 18  23   9   0 113]]

# %% [markdown]
# #### heatmap

# %%
sns.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>

# %%
acc5 = accuracy_score(y_test, y_pred)
print(f"Accuracy score: {acc5}")
# Out:
# Accuracy score: 0.7240437158469946

# %% [markdown]
# ### random forest algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
forest= RandomForestClassifier(n_estimators =40, random_state = 0)
forest.fit(X_train,y_train)
RandomForestClassifier(n_estimators=40, random_state=0)
y_pred = forest.predict(X_test)
cm = confusion_matrix(y_test,y_pred)

# %% [markdown]
# #### heatmap

# %%
sns.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        11
#            1       0.25      0.13      0.17        31
#            2       0.95      0.93      0.94       155
#            3       1.00      0.17      0.29         6
#            4       0.75      0.87      0.81       163
#
#     accuracy                           0.80       366
#    macro avg       0.59      0.42      0.44       366
# weighted avg       0.77      0.80      0.78       366

# %%
acc6 = forest.score(X_test,y_test)
print(acc6)
# Out:
# 0.7950819672131147

# %% [markdown]
# ## Comparing all the model with  their accuracy

# %%
mylist=[]
mylist2=[]
mylist.append(acc1)
mylist2.append("Logistic Regression")
mylist.append(acc2)
mylist2.append("SVM")
mylist.append(acc3)
mylist2.append("KNN")
mylist.append(acc4)
mylist2.append("Naive Bayes")
mylist.append(acc5)
mylist2.append("DTR")
mylist.append(acc6)
mylist2.append("RF")
plt.rcParams['figure.figsize']=8,6
sns.set_style("darkgrid")
plt.figure(figsize=(22,8))
ax = sns.barplot(x=mylist2, y=mylist, palette = "mako", saturation =1.5)
plt.xlabel("Classification Models", fontsize = 20 )
plt.ylabel("Accuracy", fontsize = 20)

plt.xticks(fontsize = 11, horizontalalignment = 'center', rotation = 8)
plt.yticks(fontsize = 13)
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:.2%}', (x + width/2, y + height*1.02), ha='center', fontsize = 'x-large')
plt.show()

# %% [markdown]
#  ### Hence , we can conclude  that the Naive Bayes Algorithm is the best.
